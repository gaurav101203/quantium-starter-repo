# %%
import pandas as pd

# %%
df = pd.read_csv(filepath_or_buffer=".\data\daily_sales_data_0.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\yadav\AppData\Local\Temp\ipykernel_45700\1484177390.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv(filepath_or_buffer=".\data\daily_sales_data_0.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 13720 entries, 0 to 13719
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   product   13720 non-null  str
#  1   price     13720 non-null  str
#  2   quantity  13720 non-null  int64
#  3   date      13720 non-null  str
#  4   region    13720 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 536.1 KB
